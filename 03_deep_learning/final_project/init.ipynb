# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting spotipy
#   Downloading spotipy-2.20.0-py3-none-any.whl (27 kB)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.8/661.8 KB 30.7 MB/s eta 0:00:00
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting thefuzz
#   Downloading thefuzz-0.19.0-py2.py3-none-any.whl (17 kB)
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 23.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dufte
#   Downloading dufte-0.2.29-py3-none-any.whl (8.4 kB)
# Collecting vapeplot
#   Downloading vapeplot-0.0.8.tar.gz (12 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting redis>=3.5.3
#   Downloading redis-4.3.4-py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.2/246.2 KB 46.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.15.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from spotipy->-r ./requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spotipy->-r ./requirements.txt (line 1)) (1.26.9)
# Requirement already satisfied: requests>=2.25.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spotipy->-r ./requirements.txt (line 1)) (2.27.1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from python-Levenshtein->-r ./requirements.txt (line 3)) (58.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 80.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from sentence-transformers->-r ./requirements.txt (line 5)) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from sentence-transformers->-r ./requirements.txt (line 5)) (1.11.0)
# Requirement already satisfied: torchvision in /shared-libs/python3.9/py/lib/python3.9/site-packages (from sentence-transformers->-r ./requirements.txt (line 5)) (0.12.0)
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from sentence-transformers->-r ./requirements.txt (line 5)) (1.22.4)
# Requirement already satisfied: scikit-learn in /shared-libs/python3.9/py/lib/python3.9/site-packages (from sentence-transformers->-r ./requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: scipy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from sentence-transformers->-r ./requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: nltk in /shared-libs/python3.9/py/lib/python3.9/site-packages (from sentence-transformers->-r ./requirements.txt (line 5)) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 83.5 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 KB 28.4 MB/s eta 0:00:00
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 KB 25.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from dufte->-r ./requirements.txt (line 7)) (3.5.2)
# Requirement already satisfied: packaging>=20.9 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers->-r ./requirements.txt (line 5)) (21.3)
# Requirement already satisfied: filelock in /shared-libs/python3.9/py/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers->-r ./requirements.txt (line 5)) (3.7.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers->-r ./requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: async-timeout>=4.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from redis>=3.5.3->spotipy->-r ./requirements.txt (line 1)) (4.0.2)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.25.0->spotipy->-r ./requirements.txt (line 1)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.25.0->spotipy->-r ./requirements.txt (line 1)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.25.0->spotipy->-r ./requirements.txt (line 1)) (2022.5.18.1)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 76.5 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->-r ./requirements.txt (line 5)) (2022.6.2)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->dufte->-r ./requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->dufte->-r ./requirements.txt (line 7)) (9.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->dufte->-r ./requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->dufte->-r ./requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->dufte->-r ./requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->dufte->-r ./requirements.txt (line 7)) (4.33.3)
# Requirement already satisfied: click in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk->sentence-transformers->-r ./requirements.txt (line 5)) (8.1.3)
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk->sentence-transformers->-r ./requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn->sentence-transformers->-r ./requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from deprecated>=1.2.3->redis>=3.5.3->spotipy->-r ./requirements.txt (line 1)) (1.14.1)
# Building wheels for collected packages: python-Levenshtein, sentence-transformers, bs4, vapeplot
#   Building wheel for python-Levenshtein (setup.py): started
#   Building wheel for python-Levenshtein (setup.py): finished with status 'done'
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp39-cp39-linux_x86_64.whl size=83308 sha256=af55ae47853af112bc5588cedb65424e99b40a3e09afbb64442d1ebeede09384
#   Stored in directory: /root/.cache/pip/wheels/46/4a/6c/164a1d9dd67c82d208f19d869ad0a517a0c5a6117f608c53e6
#   Building wheel for sentence-transformers (setup.py): started
#   Building wheel for sentence-transformers (setup.py): finished with status 'done'
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=5b007e313eecb24ece4198fc1c4ea7127b2011ad99324bc9702cd210c804e8d0
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=39e270b9e745079ec5330f23f8c400858092f3b4bbd78f91bfa9f7197dfd0bf7
#   Stored in directory: /root/.cache/pip/wheels/73/2b/cb/099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
#   Building wheel for vapeplot (setup.py): started
#   Building wheel for vapeplot (setup.py): finished with status 'done'
#   Created wheel for vapeplot: filename=vapeplot-0.0.8-py3-none-any.whl size=11029 sha256=2f84ac1d32a0b2d7a564b6cb1811d0b7630092aa0b0710d9cd8ea16edbcc6012
#   Stored in directory: /root/.cache/pip/wheels/50/ca/97/b9493c7d379b05146b619cde1449bec56fe2540146d9075d1b
# Successfully built python-Levenshtein sentence-transformers bs4 vapeplot
# Installing collected packages: tokenizers, thefuzz, sentencepiece, soupsieve, pyyaml, python-Levenshtein, deprecated, redis, huggingface-hub, beautifulsoup4, vapeplot, transformers, spotipy, dufte, bs4, sentence-transformers
# Successfully installed beautifulsoup4-4.11.1 bs4-0.0.1 deprecated-1.2.13 dufte-0.2.29 huggingface-hub-0.8.1 python-Levenshtein-0.12.2 pyyaml-6.0 redis-4.3.4 sentence-transformers-2.2.2 sentencepiece-0.1.96 soupsieve-2.3.2.post1 spotipy-2.20.0 thefuzz-0.19.0 tokenizers-0.12.1 transformers-4.20.1 vapeplot-0.0.8
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=eb02c87d-b537-48b1-9a25-eb017d0bc84f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
